# %%
import csv
tweets = []
with open('files/enero.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[13])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2142 lines.

# %%
from generateWordCloud import generateWordCloud

# %%
cloud = generateWordCloud(tweets)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/febrero.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[13])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2204 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/marzo.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[13])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2216 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/abril.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[13])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2350 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/mayo.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[13])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2354 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/junio.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[13])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2372 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/julio.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[13])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2324 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/agosto.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[13])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2324 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
