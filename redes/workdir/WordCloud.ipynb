# %%
import csv
tweets = []
with open('files/clean_enero.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[0])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2142 lines.

# %%
from generateWordCloud import generateWordCloud

# %%
cloud = generateWordCloud(tweets)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/clean_febrero.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[0])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2204 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/clean_marzo.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[0])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2216 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/clean_abril.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[0])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2350 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/clean_mayo.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[0])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2354 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/clean_junio.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[0])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2372 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/clean_julio.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[0])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2324 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
import csv
tweets = []
with open('files/clean_agosto.csv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        line_count += 1
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            tweets.append(row[0])
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Processed 2324 lines.

# %%
cloud = generateWordCloud(tweets)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
from sentimentAnalisys import analyze
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\documents\analisisredessociales\redes\lib\site-packages\keras\__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ModuleNotFoundError: No module named 'tensorflow'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-61-9bb31abee346> in <module>
# ----> 1 from sentimentAnalisys import analyze
#
# D:\Documents\analisisRedesSociales\redes\workdir\sentimentAnalisys.py in <module>
# ----> 1 from sentiment_analysis_spanish import sentiment_analysis
#       2 def analyze(text):
#       3     sentiment = sentiment_analysis.SentimentAnalysisSpanish()
#       4     result = sentiment.sentiment(text)
# ...

# %%
analyze("Me gusto mucho pienso que es bastante útil")
# Out:
# 0
